# %%
import graphviz
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange
import numpy as np
from graphviz import *
import locale
from locale import atof
locale.setlocale(locale.LC_NUMERIC, '')
'en_US.UTF-8'
import pandas as pd
from six import StringIO  
from IPython.display import Image 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import export_graphviz
import pydotplus
from unidecode import unidecode
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
col_names = ['date','rise','Доходность ОФЗ по сроку до 1 года','Ключевая ставка','Ставка по вкладам в долларах до 1 года','StavkaVRub','Нефть марки Юралс, долл./барр','Индекс потребительских цен, ед.','М0, руб','М2, руб','Курс доллара к рублю, руб','Номинальная средняя з/п, руб']
test = pd.read_csv("/home/man/Desktop/bst_ds.csv",sep=';', header = 0, decimal=',', names=col_names, usecols=col_names)
df1 = pd.DataFrame(data=test)
df1['date'] = pd.to_datetime(df1['date'],format='%d.%m.%Y')
df1['month'] = df1['date'].dt.month
df1['year'] = df1['date'].dt.year
#df1 = df1.drop("date",axis =1)
df1.sample(4)
# Out:
#          date      rise  Доходность ОФЗ по сроку до 1 года  Ключевая ставка  \
# 2  2011-03-01  106845.0                                5.0              8.0
# 32 2013-09-01    5070.0                                6.1              5.5
# 61 2016-02-01  269297.0                                9.9             11.0
# 60 2016-01-01 -454791.0                               10.3             11.0
#
#     Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 2                                      3.1         4.2
# 32                                     2.4         5.4
# 61                                     1.6         7.7
# 60                                     1.6         8.2
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 2                             114                            107.7  5647000
# 32                            112                            122.8  7726800
# 61                             33                            159.5  8282800
# 60                             31                            158.5  8197700
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month  \
# 2     19789                         28                         22673      3
# 32    28353                         33                         29346      9
# 61    34310                         77                         33873      2
# 60    33967                         76                         32660      1
#
#     year
# 2   2011
# 32  2013
# 61  2016
# 60  2016

# %%
df1.shape
# Out:
# (84, 14)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    84 non-null     datetime64[ns]
#  1   rise                                    72 non-null     float64
#  2   Доходность ОФЗ по сроку до 1 года       84 non-null     float64
#  3   Ключевая ставка                         84 non-null     float64
#  4   Ставка по вкладам в долларах до 1 года  84 non-null     float64
#  5   StavkaVRub                              84 non-null     float64
#  6   Нефть марки Юралс, долл./барр           84 non-null     int64
#  7   Индекс потребительских цен, ед.         84 non-null     float64
#  8   М0, руб                                 84 non-null     int64
#  9   М2, руб                                 84 non-null     int64
#  10  Курс доллара к рублю, руб               84 non-null     int64
#  11  Номинальная средняя з/п, руб            84 non-null     int64
#  12  month                                   84 non-null     int64
#  13  year                                    84 non-null     int64
# dtypes: datetime64[ns](1), float64(6), int64(7)
# memory usage: 9.3 KB

# %%
df1.isnull().sum()
# Out:
# date                                       0
# rise                                      12
# Доходность ОФЗ по сроку до 1 года          0
# Ключевая ставка                            0
# Ставка по вкладам в долларах до 1 года     0
# StavkaVRub                                 0
# Нефть марки Юралс, долл./барр              0
# Индекс потребительских цен, ед.            0
# М0, руб                                    0
# М2, руб                                    0
# Курс доллара к рублю, руб                  0
# Номинальная средняя з/п, руб               0
# month                                      0
# year                                       0
# dtype: int64

# %% [markdown]
# # 1.Separate the NULL values

# %% [markdown]
# Further, Separate the NULL values of rise column and consider as test data:

# %%
#separate NULL values from 'rise' feature:
test_data = df1[df1.rise.isnull()] # or test_data = df1[df1['rise'].isnull()]

# %%
test_data
# Out:
#          date  rise  Доходность ОФЗ по сроку до 1 года  Ключевая ставка  \
# 72 2017-01-01   NaN                                8.4             10.0
# 73 2017-02-01   NaN                                8.8             10.0
# 74 2017-03-01   NaN                                9.0              9.8
# 75 2017-04-01   NaN                                8.7              9.8
# 76 2017-05-01   NaN                                8.3              9.3
# 77 2017-06-01   NaN                                8.0              9.0
# 78 2017-07-01   NaN                                8.1              9.0
# 79 2017-08-01   NaN                                7.9              9.0
# 80 2017-09-01   NaN                                7.6              8.5
# 81 2017-10-01   NaN                                7.5              8.3
# 82 2017-11-01   NaN                                7.4              8.3
# 83 2017-12-01   NaN                                7.0              7.8
#
#     Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 72                                     0.8         6.5
# 73                                     0.8         6.3
# 74                                     0.8         5.9
# 75                                     0.5         6.3
# 76                                     0.8         6.1
# 77                                     0.7         5.7
# 78                                     0.7         6.1
# 79                                     0.7         6.1
# 80                                     0.7         5.3
# 81                                     0.6         5.7
# 82                                     0.6         5.2
# 83                                     0.7         5.3
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 72                             55                            166.4  8628900
# 73                             55                            166.8  8711600
# 74                             52                            167.0  8697700
# 75                             53                            167.6  8936600
# 76                             51                            168.2  8907000
# 77                             47                            169.2  9066500
# 78                             49                            169.3  9174300
# 79                             52                            168.4  9194600
# 80                             57                            168.2  9225200
# 81                             58                            168.5  9246600
# 82                             63                            168.9  9281212
# 83                             65                            169.6  9974472
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month  \
# 72    38017                         60                         34422      1
# 73    38475                         58                         35497      2
# 74    38555                         58                         37899      3
# 75    38664                         56                         39225      4
# 76    39223                         57                         39679      5
# 77    39623                         58                         41454      6
# 78    39276                         60                         38073      7
# 79    39419                         60                         37099      8
# 80    39571                         58                         38047      9
# 81    39566                         58                         38333     10
# 82    40102                         59                         38848     11
# 83    42372                         59                         50500     12
#
#     year
# 72  2017
# 73  2017
# 74  2017
# 75  2017
# 76  2017
# 77  2017
# 78  2017
# 79  2017
# 80  2017
# 81  2017
# 82  2017
# 83  2017

# %% [markdown]
# # 2.Drop the NULL values from the dataframe df1 and consider it as train data

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#          date      rise  Доходность ОФЗ по сроку до 1 года  Ключевая ставка  \
# 0  2011-01-01  -79049.0                                5.2              7.8
# 1  2011-02-01  180475.0                                5.1              8.0
# 2  2011-03-01  106845.0                                5.0              8.0
# 3  2011-04-01  224890.0                                4.6              8.0
# 4  2011-05-01   45856.0                                4.8              8.3
# ..        ...       ...                                ...              ...
# 67 2016-08-01   92168.0                                9.3             10.5
# 68 2016-09-01   20272.0                                9.0             10.0
# 69 2016-10-01   72037.0                                9.0             10.0
# 70 2016-11-01  172323.0                                8.9             10.0
# 71 2016-12-01  889085.0                                8.7             10.0
#
#     Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 0                                      2.9         4.5
# 1                                      3.1         4.4
# 2                                      3.1         4.2
# 3                                      2.6         4.1
# 4                                      2.6         4.1
# ..                                     ...         ...
# 67                                     0.9         6.8
# 68                                     0.8         6.0
# 69                                     0.7         6.0
# 70                                     0.7         6.6
# 71                                     0.8         6.5
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 0                              96                            106.2  5532900
# 1                             104                            107.0  5613700
# 2                             114                            107.7  5647000
# 3                             123                            108.1  5863400
# 4                             114                            108.6  5893400
# ..                            ...                              ...      ...
# 67                             46                            163.0  8517600
# 68                             46                            163.3  8557800
# 69                             50                            164.0  8459500
# 70                             46                            164.8  8425200
# 71                             54                            165.4  9076100
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month  \
# 0     19308                         30                         20669      1
# 1     19537                         29                         20680      2
# 2     19789                         28                         22673      3
# 3     20021                         28                         22519      4
# 4     20161                         28                         22779      5
# ..      ...                        ...                           ...    ...
# 67    36170                         65                         35405      8
# 68    36149                         65                         35843      9
# 69    36051                         63                         35749     10
# 70    36433                         64                         36195     11
# 71    38418                         62                         47554     12
#
#     year
# 0   2011
# 1   2011
# 2   2011
# 3   2011
# 4   2011
# ..   ...
# 67  2016
# 68  2016
# 69  2016
# 70  2016
# 71  2016
#
# [72 rows x 14 columns]

# %%
ax, fig = plt.subplots(figsize=[15,7])
correlation_matrix = df1.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# train_data := rows from the data frame (df1), where column "rise" has no NULL values

# %%
df1.isnull().sum()
# Out:
# date                                      0
# rise                                      0
# Доходность ОФЗ по сроку до 1 года         0
# Ключевая ставка                           0
# Ставка по вкладам в долларах до 1 года    0
# StavkaVRub                                0
# Нефть марки Юралс, долл./барр             0
# Индекс потребительских цен, ед.           0
# М0, руб                                   0
# М2, руб                                   0
# Курс доллара к рублю, руб                 0
# Номинальная средняя з/п, руб              0
# month                                     0
# year                                      0
# dtype: int64

# %% [markdown]
# # 3.Create "X_train" and "y_train" from data frame (df1)

# %%
#create the "y_train"
# "y_train" means rows from the df1.rise with no NULL values
y_train = df1.rise

#Normalization
y_train = (y_train-min(y_train))/(max(y_train)-min(y_train))

# %%
y_train
# Out:
# 0     0.304868
# 1     0.466867
# 2     0.420906
# 3     0.494592
# 4     0.382835
#         ...
# 67    0.411744
# 68    0.366866
# 69    0.399178
# 70    0.461778
# 71    0.909194
# Name: rise, Length: 72, dtype: float64

# %%
# "X_train" means data frame (df1 )without df1.rise feature with non NULL values
X_train = df1.drop(['date','rise','year'],axis=1)

# %%
X_train
# Out:
#     Доходность ОФЗ по сроку до 1 года  Ключевая ставка  \
# 0                                 5.2              7.8
# 1                                 5.1              8.0
# 2                                 5.0              8.0
# 3                                 4.6              8.0
# 4                                 4.8              8.3
# ..                                ...              ...
# 67                                9.3             10.5
# 68                                9.0             10.0
# 69                                9.0             10.0
# 70                                8.9             10.0
# 71                                8.7             10.0
#
#     Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 0                                      2.9         4.5
# 1                                      3.1         4.4
# 2                                      3.1         4.2
# 3                                      2.6         4.1
# 4                                      2.6         4.1
# ..                                     ...         ...
# 67                                     0.9         6.8
# 68                                     0.8         6.0
# 69                                     0.7         6.0
# 70                                     0.7         6.6
# 71                                     0.8         6.5
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 0                              96                            106.2  5532900
# 1                             104                            107.0  5613700
# 2                             114                            107.7  5647000
# 3                             123                            108.1  5863400
# 4                             114                            108.6  5893400
# ..                            ...                              ...      ...
# 67                             46                            163.0  8517600
# 68                             46                            163.3  8557800
# 69                             50                            164.0  8459500
# 70                             46                            164.8  8425200
# 71                             54                            165.4  9076100
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month
# 0     19308                         30                         20669      1
# 1     19537                         29                         20680      2
# 2     19789                         28                         22673      3
# 3     20021                         28                         22519      4
# 4     20161                         28                         22779      5
# ..      ...                        ...                           ...    ...
# 67    36170                         65                         35405      8
# 68    36149                         65                         35843      9
# 69    36051                         63                         35749     10
# 70    36433                         64                         36195     11
# 71    38418                         62                         47554     12
#
# [72 rows x 11 columns]

# %%
# Saving feature names for later use
feature_list = list(df1.columns)
# Convert to numpy array
X_train = np.array(X_train)

# %%
# Using Skicit-learn to split KNOWN data into training and testing sets, to research model on KNOWN data at first
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(X_train, y_train, test_size = 0.25, random_state = 42)

# %%
print('Training features shape:', train_features.shape)
print('Training labels shape:', train_labels.shape)
print('Testing features shape:', test_features.shape)
print('Testing features shape:', test_labels.shape)
# Out:
# Training features shape: (54, 11)
# Training labels shape: (54,)
# Testing features shape: (18, 11)
# Testing features shape: (18,)

# %%
# The baseline predictions are the rise of deposits
baseline_preds = test_features[:, feature_list.index('rise')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# Average baseline error:  9.31

# %% [markdown]
# # 4.Build the model

# %% [markdown]
# Prepairing the ML model(regression) on training the dataset and predicting the missing values in column rise

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
#train the model on train dataset (X_train, y_train):
lr.fit(train_features, train_labels)
# Out:
# LinearRegression()

# %%
# Use the forest's predict method on the test data
predictions = lr.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'rubles.')
# Out:
# Mean Absolute Error: 0.09 rubles.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 73.2 %.

# %%
#without dropping anything accuracy is 73.2, with all- 71,и чото там, убрав нефть и доллар, точность 72.15

# %% [markdown]
# # 5.Create the "X_test" from the test data

# %%
X_test = test_data.drop(['date','rise','year'],axis=1)

# %%
X_test
# Out:
#     Доходность ОФЗ по сроку до 1 года  Ключевая ставка  \
# 72                                8.4             10.0
# 73                                8.8             10.0
# 74                                9.0              9.8
# 75                                8.7              9.8
# 76                                8.3              9.3
# 77                                8.0              9.0
# 78                                8.1              9.0
# 79                                7.9              9.0
# 80                                7.6              8.5
# 81                                7.5              8.3
# 82                                7.4              8.3
# 83                                7.0              7.8
#
#     Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 72                                     0.8         6.5
# 73                                     0.8         6.3
# 74                                     0.8         5.9
# 75                                     0.5         6.3
# 76                                     0.8         6.1
# 77                                     0.7         5.7
# 78                                     0.7         6.1
# 79                                     0.7         6.1
# 80                                     0.7         5.3
# 81                                     0.6         5.7
# 82                                     0.6         5.2
# 83                                     0.7         5.3
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 72                             55                            166.4  8628900
# 73                             55                            166.8  8711600
# 74                             52                            167.0  8697700
# 75                             53                            167.6  8936600
# 76                             51                            168.2  8907000
# 77                             47                            169.2  9066500
# 78                             49                            169.3  9174300
# 79                             52                            168.4  9194600
# 80                             57                            168.2  9225200
# 81                             58                            168.5  9246600
# 82                             63                            168.9  9281212
# 83                             65                            169.6  9974472
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month
# 72    38017                         60                         34422      1
# 73    38475                         58                         35497      2
# 74    38555                         58                         37899      3
# 75    38664                         56                         39225      4
# 76    39223                         57                         39679      5
# 77    39623                         58                         41454      6
# 78    39276                         60                         38073      7
# 79    39419                         60                         37099      8
# 80    39571                         58                         38047      9
# 81    39566                         58                         38333     10
# 82    40102                         59                         38848     11
# 83    42372                         59                         50500     12

# %% [markdown]
# # 6.Applying the model on X_test and predicting the missing values

# %%
#Apply the trained model on "X_test"
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([0.22576191, 0.22778667, 0.33081643, 0.41278359, 0.4380311 ,
#        0.53733082, 0.4021953 , 0.36342791, 0.41296685, 0.43076112,
#        0.45536562, 1.00904856])

# %% [markdown]
# # 7.Replace missing values with predicted values

# %%
#Unnormilize back
y_pred = y_pred*(max(df1.rise)-min(df1.rise)) + min(df1.rise)

test_data.loc[test_data.rise.isnull(), "rise"] = y_pred
# Out:
# /home/man/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
test_data
# Out:
#          date          rise  Доходность ОФЗ по сроку до 1 года  \
# 72 2017-01-01 -2.057765e+05                                8.4
# 73 2017-02-01 -2.025328e+05                                8.8
# 74 2017-03-01 -3.747875e+04                                9.0
# 75 2017-04-01  9.383296e+04                                8.7
# 76 2017-05-01  1.342796e+05                                8.3
# 77 2017-06-01  2.933581e+05                                8.0
# 78 2017-07-01  7.687047e+04                                8.1
# 79 2017-08-01  1.476496e+04                                7.9
# 80 2017-09-01  9.412655e+04                                7.6
# 81 2017-10-01  1.226330e+05                                7.5
# 82 2017-11-01  1.620495e+05                                7.4
# 83 2017-12-01  1.049052e+06                                7.0
#
#     Ключевая ставка  Ставка по вкладам в долларах до 1 года  StavkaVRub  \
# 72             10.0                                     0.8         6.5
# 73             10.0                                     0.8         6.3
# 74              9.8                                     0.8         5.9
# 75              9.8                                     0.5         6.3
# 76              9.3                                     0.8         6.1
# 77              9.0                                     0.7         5.7
# 78              9.0                                     0.7         6.1
# 79              9.0                                     0.7         6.1
# 80              8.5                                     0.7         5.3
# 81              8.3                                     0.6         5.7
# 82              8.3                                     0.6         5.2
# 83              7.8                                     0.7         5.3
#
#     Нефть марки Юралс, долл./барр  Индекс потребительских цен, ед.  М0, руб  \
# 72                             55                            166.4  8628900
# 73                             55                            166.8  8711600
# 74                             52                            167.0  8697700
# 75                             53                            167.6  8936600
# 76                             51                            168.2  8907000
# 77                             47                            169.2  9066500
# 78                             49                            169.3  9174300
# 79                             52                            168.4  9194600
# 80                             57                            168.2  9225200
# 81                             58                            168.5  9246600
# 82                             63                            168.9  9281212
# 83                             65                            169.6  9974472
#
#     М2, руб  Курс доллара к рублю, руб  Номинальная средняя з/п, руб  month  \
# 72    38017                         60                         34422      1
# 73    38475                         58                         35497      2
# 74    38555                         58                         37899      3
# 75    38664                         56                         39225      4
# 76    39223                         57                         39679      5
# 77    39623                         58                         41454      6
# 78    39276                         60                         38073      7
# 79    39419                         60                         37099      8
# 80    39571                         58                         38047      9
# 81    39566                         58                         38333     10
# 82    40102                         59                         38848     11
# 83    42372                         59                         50500     12
#
#     year
# 72  2017
# 73  2017
# 74  2017
# 75  2017
# 76  2017
# 77  2017
# 78  2017
# 79  2017
# 80  2017
# 81  2017
# 82  2017
# 83  2017

# %%
x1 = [i for i in test_data['date']]
y1 = [f for f in test_data['rise']]
x2 = [i for i in df1['date']]
y2 = [f for f in df1['rise']]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 7))
axes[0].plot(x1, y1)
axes[1].plot(x2, y2)
